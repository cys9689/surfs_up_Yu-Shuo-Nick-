# %%
#import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine=create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base=automap_base()
# reflect the tables
Base.prepare(engine,reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement=Base.classes.measurement
Station=Base.classes.station

# %%
# Create our session (link) from Python to the DB
session=Session(engine)

# %%
#query date and precipitation columns
results=session.query(Measurement.date,Measurement.prcp).all()

# %%
#print out results
for result in results:
    print(result)
# Out:
# ('2010-01-01', 0.08)
# ('2010-01-02', 0.0)
# ('2010-01-03', 0.0)
# ('2010-01-04', 0.0)
# ('2010-01-06', None)
# ('2010-01-07', 0.06)
# ('2010-01-08', 0.0)
# ('2010-01-09', 0.0)
# ('2010-01-10', 0.0)
# ('2010-01-11', 0.01)
# ('2010-01-12', 0.0)
# ('2010-01-14', 0.0)
# ('2010-01-15', 0.0)
# ('2010-01-16', 0.0)
# ('2010-01-17', 0.0)
# ('2010-01-18', 0.0)
# ('2010-01-19', 0.0)
# ('2010-01-20', 0.0)
# ('2010-01-21', 0.0)
# ('2010-01-22', 0.0)
# ('2010-01-23', 0.0)
# ('2010-01-24', 0.01)
# ('2010-01-25', 0.0)
# ('2010-01-26', 0.04)
# ('2010-01-27', 0.12)
# ('2010-01-28', 0.0)
# ('2010-01-30', None)
# ('2010-01-31', 0.03)
# ('2010-02-01', 0.01)
# ('2010-02-03', None)
# ('2010-02-04', 0.01)
# ('2010-02-05', 0.0)
# ('2010-02-06', 0.0)
# ('2010-02-07', 0.0)
# ('2010-02-08', 0.0)
# ('2010-02-09', 0.0)
# ('2010-02-11', 0.0)
# ('2010-02-12', 0.02)
# ('2010-02-13', 0.01)
# ('2010-02-14', 0.0)
# ('2010-02-15', 0.0)
# ('2010-02-16', 0.0)
# ('2010-02-17', 0.0)
# ('2010-02-19', None)
# ...

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
#Starting from the last data point in the database. 
prev_year=dt.date(2017,8,23)
# Calculate the date one year from the last date in data set.
prev_year=dt.date(2017,8,23)-dt.timedelta(days=365)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=prev_year).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# How many stations are available in this dataset?
session.query(func.count(Station.station)).all()
# Out:
# [(9)]

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
session.query(Measurement.station,func.count(Measurement.station)).\
group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurement.tobs)).\
filter(Measurement.station=='USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
results=session.query(Measurement.tobs).\
filter(Measurement.station=='USC00519281').\
filter(Measurement.date>=prev_year).all()

df=pd.DataFrame(results,columns=['tobs'])
df.plot.hist(bins=12)
plt.tight_layout()

# %%
Measurement.tobs

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2012-02-28','2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %% [markdown]
# # Challenge

# %% [markdown]
# July 2015

# %%
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2015-07-01','2015-07-31'))
# Out:
# [(67.0, 77.625, 84.0)]

# %%
july_1st=dt.date(2015,7,1)
# Calculate the date 31 days from the last date in data set.
july_31th=dt.date(2015,7,1)+dt.timedelta(days=30)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=july_1st).filter(Measurement.date<=july_31th).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
df.describe()
# Out:
#        precipitation
# count     159.000000
# mean        0.161698
# std         0.391584
# min         0.000000
# 25%         0.000000
# 50%         0.010000
# 75%         0.135000
# max         2.590000

# %% [markdown]
# July 2016

# %%
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2016-07-01','2016-07-31'))
# Out:
# [(71.0, 77.45989304812834, 83.0)]

# %%
july_1st=dt.date(2016,7,1)
# Calculate the date 31 days from the last date in data set.
july_31th=dt.date(2016,7,1)+dt.timedelta(days=30)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=july_1st).filter(Measurement.date<=july_31th).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
df.describe()
# Out:
#        precipitation
# count     163.000000
# mean        0.401656
# std         1.164754
# min         0.000000
# 25%         0.000000
# 50%         0.050000
# 75%         0.245000
# max         9.640000

# %% [markdown]
# July 2017

# %%
july_1st=dt.date(2017,7,1)
# Calculate the date 31 days from the last date in data set.
july_31th=dt.date(2017,7,1)+dt.timedelta(days=30)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=july_1st).filter(Measurement.date<=july_31th).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
df.describe()
# Out:
#        precipitation
# count     176.000000
# mean        0.134773
# std         0.386084
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.112500
# max         4.000000

# %% [markdown]
# 2015 December

# %%
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2015-12-01','2015-12-30'))
# Out:
# [(65.0, 73.50279329608938, 82.0)]

# %%
Dec_1st=dt.date(2015,12,1)
# Calculate the date 31 days from the last date in data set.
Dec_30th=dt.date(2015,12,1)+dt.timedelta(days=30)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=Dec_1st).filter(Measurement.date<=Dec_30th).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
df.describe()
# Out:
#        precipitation
# count     162.000000
# mean        0.169506
# std         0.290003
# min         0.000000
# 25%         0.010000
# 50%         0.075000
# 75%         0.187500
# max         2.210000

# %% [markdown]
# 2016 December

# %%
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2016-12-01','2016-12-30'))
# Out:
# [(60.0, 71.2051282051282, 78.0)]

# %%
Dec_1st=dt.date(2016,12,1)
# Calculate the date 31 days from the last date in data set.
Dec_30th=dt.date(2016,12,1)+dt.timedelta(days=30)
# Perform a query to retrieve the data and precipitation scores
results=[]
results=session.query(Measurement.date,Measurement.prcp).filter(Measurement.date>=Dec_1st).filter(Measurement.date<=Dec_30th).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
df=pd.DataFrame(results,columns=['date','precipitation'])
df.set_index(df['date'],inplace=True)
# Sort the dataframe by date
df=df.sort_index()

# Use Pandas Plotting with Matplotlib to plot the data
df.plot()

# %%
df.describe()
# Out:
#        precipitation
# count     178.000000
# mean        0.199494
# std         0.342967
# min         0.000000
# 25%         0.020000
# 50%         0.060000
# 75%         0.247500
# max         2.370000

# %% [markdown]
# 2017 December

# %%
def clac_temps(start_date,end_date):
    return session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).\
        filter(Measurement.date>=start_date).filter(Measurement.date<=end_date).all()

print(clac_temps('2017-12-01','2017-12-30'))
# Out:
# [(None, None, None)]

# %% [markdown]
# # Comparison Between July and December(2015-2017)

# %% [markdown]
#        W. Avy likes your analysis, but he feels there is one piece of information missing: seasonal data. He’s asked you to gather data on the seasons of Oahu and determine whether the seasons could affect the surf and ice cream shop business. Specifically, are there certain times of the year when business might be slower, or the type of customer could be different?
#         To answer W. Avy's Question, we had use our Oahu's seasonal weather data to run for statistical result. From the above code's result table, we can see in 2015 July the maximum precipitation rate is 2.59, in comparison with December in 2015-2.21 maximum precipitation rate. The differences is small. However, when it comes to 2016, the precipitation rate in july has goes up to 9.64, which December maintain in 2.37. The difference is realtive large. ALthough, we know the 2017 July's maximum precipitation rate is 4, we don't have data of December 2017. Therefore, we cannot make any conclusion based on that. In addition, the temperature in Decenmber is always lower than July, this is also a consideration.

# %% [markdown]
# # Recommendation for future study

# %% [markdown]
# 1. My first recommendation is to include more months than only picking july and december. Instead of picking individual month, we should consider to combine the date with multiple months. For example: assume May-July as summer and say November- January is winter. Do the comparison with these two season might be able to provide more information
# 2. My second recommendation is to use mroe than the statistical(describe() function) result. For example : combination of the line chart. In this challenge we only worry about the weather(rainy). So we can combine the different season's precipitation rate into a line chart for better visulization
# 3. Lastly, we should focus on more aspect than just precipitation. Sometimes, windy is also very ideal for customer. In order to do that, we needs to have mroe weather data. So gather more date is my final recommendation
